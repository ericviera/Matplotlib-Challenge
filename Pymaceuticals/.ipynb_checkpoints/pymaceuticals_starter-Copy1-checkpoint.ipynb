# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np 

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
comb_df = pd.merge(mouse_metadata,study_results, on='Mouse ID')
# Display the data table for preview
comb_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
comb_df["Mouse ID"].count()
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

comb_dp=comb_df[comb_df.duplicated(['Mouse ID','Timepoint'])]
comb_dp
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
comb_drp=comb_df.drop_duplicates(['Mouse ID','Timepoint'])
comb_drp
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
comb_drp['Mouse ID'].count()
# Out:
# 1888

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summ=comb_drp['Drug Regimen'].unique()
summ
# This method is the most straighforward, creating multiple series and putting them all together at the end.
#comb_drp['Tumor Volume (mm3)'].describe()
# Out:
# array(['Ramicane', 'Capomulin', 'Infubinol', 'Placebo', 'Ceftamin',
#        'Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol'],
#       dtype=object)

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
summ=pd.DataFrame(comb_drp.groupby('Drug Regimen').count())
summ
# Out:
#               Mouse ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin          230  230         230         230        230
# Ceftamin           178  178         178         178        178
# Infubinol          178  178         178         178        178
# Ketapril           188  188         188         188        188
# Naftisol           186  186         186         186        186
# Placebo            181  181         181         181        181
# Propriva           156  156         156         156        156
# Ramicane           228  228         228         228        228
# Stelasyn           181  181         181         181        181
# Zoniferol          182  182         182         182        182
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                    230               230
# Ceftamin                     178               178
# Infubinol                    178               178
# ...

# %%
summ=pd.DataFrame(comb_drp.groupby('Drug Regimen').count())
summ["Mean"] = pd.DataFrame(comb_drp.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean())
summ["Median"] = pd.DataFrame(comb_drp.groupby("Drug Regimen")["Tumor Volume (mm3)"].median())
summ["Variance"] = pd.DataFrame(comb_drp.groupby("Drug Regimen")["Tumor Volume (mm3)"].var())
summ["Standard Deviation"] = pd.DataFrame(comb_drp.groupby("Drug Regimen")["Tumor Volume (mm3)"].std())
summ["SEM"] = pd.DataFrame(comb_drp.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem())
summ = summ[['Mouse ID','Mean','Median','Variance','Standard Deviation','SEM']]
summ
# Out:
#               Mouse ID       Mean     Median   Variance  Standard Deviation  \
# Drug Regimen
# Capomulin          230  40.675741  41.557809  24.947764            4.994774
# Ceftamin           178  52.591172  51.776157  39.290177            6.268188
# Infubinol          178  52.884795  51.820584  43.128684            6.567243
# Ketapril           188  55.235638  53.698743  68.553577            8.279709
# Naftisol           186  54.331565  52.509285  66.173479            8.134708
# Placebo            181  54.033581  52.288934  61.168083            7.821003
# Propriva           156  52.393463  50.909965  43.138803            6.568014
# Ramicane           228  40.216745  40.673236  23.486704            4.846308
# Stelasyn           181  54.233149  52.431737  59.450562            7.710419
# Zoniferol          182  53.236507  51.818479  48.533355            6.966589
#
#                    SEM
# Drug Regimen
# Capomulin     0.329346
# Ceftamin      0.469821
# Infubinol     0.492236
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

total_mice= summ[['Mouse ID']]
total_mice.plot(kind="bar")
plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

x_axis = np.arange(len(summ))
tick_locations = [value for value in x_axis]

plt.figure()
plt.bar(x_axis, summ["Mouse ID"], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, summ.index, rotation="vertical")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
fvm = summ[["Mouse ID"]]

fvm.plot.pie(y='Mouse ID', figsize=(5, 5),subplots=True)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(summ["Mouse ID"],labels=summ.index.values,autopct="%1.1f%%", shadow=True, startangle=140)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
tumor_vol = comb_df.loc[(comb_df["Drug Regimen"] == "Capomulin") | (comb_df["Drug Regimen"] == "Ramicane") | (comb_df["Drug Regimen"] == "Ceftamin") | (comb_df["Drug Regimen"] == "Propriva"), :]
tumor_vol

# Start by getting the last (greatest) timepoint for each mouse
tumor_vol = tumor_vol.sort_values("Timepoint", ascending = False)
tumor_vol

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 84       z578     Ramicane    Male          11          16         45
# 1670     w151     Ceftamin    Male          24          25         45
# 1797     x822     Ceftamin    Male           3          29         45
# 59       s508     Ramicane    Male           1          17         45
# 282      l897    Capomulin    Male          17          19         45
# ...       ...          ...     ...         ...         ...        ...
# 215      w914    Capomulin    Male          24          21          0
# 1217     n630     Propriva  Female          15          29          0
# 1577     u149     Ceftamin    Male          24          29          0
# 1551     t573     Ceftamin  Female          15          27          0
# 0        k403     Ramicane    Male          21          16          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 84             30.638696                 0
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
Capomulin_treatment = comb_df.loc[(comb_df["Drug Regimen"] == "Capomulin"),:]
Capomulin_treatment
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
timepoint = Capomulin_treatment["Timepoint"]
tumor_vol = Capomulin_treatment["Tumor Volume (mm3)"]
tumor_volume_line, = plt.plot(timepoint, tumor_vol)
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')

plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
avg_weight = Capomulin_treatment.groupby(Capomulin_treatment["Mouse ID"])["Weight (g)"].mean()
avg_tumor_vol = Capomulin_treatment.groupby(Capomulin_treatment['Mouse ID'])["Tumor Volume (mm3)"].mean()
plt.scatter(avg_weight,avg_tumor_vol)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
avg_weight = Capomulin_treatment.groupby(Capomulin_treatment["Mouse ID"])["Weight (g)"].mean()
avg_tumor_vol = Capomulin_treatment.groupby(Capomulin_treatment["Mouse ID"])["Tumor Volume (mm3)"].mean()


slope, intercept, r, p, std_err = st.linregress(avg_weight, avg_tumor_vol)
regress_values = avg_weight * slope + intercept
plt.scatter(avg_weight,avg_tumor_vol)
plt.xlabel("Average Weight")
plt.ylabel("Average Volume")
plt.plot(avg_weight,regress_values,"--")
plt.xticks(avg_weight, rotation=90)
plt.show()
